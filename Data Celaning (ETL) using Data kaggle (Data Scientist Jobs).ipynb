# %% [markdown]
# # ETL stands for Extract, Transform, Load.
#
# Data from kaggle (Data Scientist Jobs).https://www.kaggle.com/datasets/andrewmvd/data-scientist-jobs/data7

# %%
# Importing necessary libraries for the project
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %% [markdown]
# # Extract

# %%
df=pd.read_csv('DataScientist.csv')
df.head(10)
# Out:
#    Unnamed: 0  index                          Job Title  \
# 0           0      0              Senior Data Scientist
# 1           1      1  Data Scientist, Product Analytics
# 2           2      2               Data Science Manager
# 3           3      3                       Data Analyst
# 4           4      4             Director, Data Science
# 5           5      5                     Data Scientist
# 6           6      6            Quantitative Researcher
# 7           7      7    Quantitative Research Associate
# 8           8      8                       AI Scientist
# 9           9      9            Quantitative Researcher
#
#                 Salary Estimate  \
# 0  $111K-$181K (Glassdoor est.)
# 1  $111K-$181K (Glassdoor est.)
# 2  $111K-$181K (Glassdoor est.)
# 3  $111K-$181K (Glassdoor est.)
# 4  $111K-$181K (Glassdoor est.)
# 5  $111K-$181K (Glassdoor est.)
# 6  $111K-$181K (Glassdoor est.)
# 7  $111K-$181K (Glassdoor est.)
# 8  $111K-$181K (Glassdoor est.)
# 9  $111K-$181K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  ABOUT HOPPER\n\nAt Hopper, we’re on a mission ...     3.5
# 1  At Noom, we use scientifically proven methods ...     4.5
# 2  Decode_M\n\nhttps://www.decode-m.com/\n\nData ...    -1.0
# 3  Sapphire Digital seeks a dynamic and driven mi...     3.4
# 4  Director, Data Science - (200537)\nDescription...     3.4
# 5  Job Brief\n\nThe ideal candidate will have pre...     2.9
# 6  Experience: Entry-level (PhD Program) or Exper...     4.4
# 7  Seeking a quant to work with senior researcher...    -1.0
# 8  Paige is a software company helping pathologis...     5.0
# 9  About the Position\n\n\nAt Jane Street, we con...     4.8
#
#                       Company Name       Location      Headquarters  \
# 0                      Hopper\n3.5   New York, NY  Montreal, Canada
# 1                     Noom US\n4.5   New York, NY      New York, NY
# 2                         Decode_M   New York, NY      New York, NY
# 3            Sapphire Digital\n3.4  Lyndhurst, NJ     Lyndhurst, NJ
# 4  United Entertainment Group\n3.4   New York, NY      New York, NY
# 5               IFG Companies\n2.9   New York, NY      Hartford, CT
# 6                PDT Partners\n4.4   New York, NY      New York, NY
# 7           Enlightenment Research   New York, NY      New York, NY
# 8                       Paige\n5.0   New York, NY      New York, NY
# 9                 Jane Street\n4.8   New York, NY      New York, NY
#
#                      Size  Founded  Type of ownership  \
# 0   501 to 1000 employees     2007  Company - Private
# 1  1001 to 5000 employees     2008  Company - Private
# 2       1 to 50 employees       -1            Unknown
# 3    201 to 500 employees     2019  Company - Private
# 4     51 to 200 employees     2007  Company - Private
# 5    201 to 500 employees     1985  Company - Private
# 6     51 to 200 employees     1993  Company - Private
# 7       1 to 50 employees       -1            Unknown
# 8       1 to 50 employees     2018  Company - Private
# 9   501 to 1000 employees     2000  Company - Private
#
#                                   Industry                  Sector  \
# 0                          Travel Agencies        Travel & Tourism
# 1                Health, Beauty, & Fitness       Consumer Services
# 2                                       -1                      -1
# 3                                 Internet  Information Technology
# 4                  Advertising & Marketing       Business Services
# 5                       Insurance Carriers               Insurance
# 6    Investment Banking & Asset Management                 Finance
# 7                                       -1                      -1
# 8  Enterprise Software & Network Solutions  Information Technology
# 9    Investment Banking & Asset Management                 Finance
#
#                     Revenue                    Competitors Easy Apply
# 0  Unknown / Non-Applicable                             -1         -1
# 1  Unknown / Non-Applicable                             -1         -1
# 2  Unknown / Non-Applicable                             -1       True
# 3  Unknown / Non-Applicable           Zocdoc, Healthgrades         -1
# 4  Unknown / Non-Applicable       BBDO, Grey Group, Droga5         -1
# 5  Unknown / Non-Applicable  Colony Specialty, Markel, RLI         -1
# 6  Unknown / Non-Applicable                             -1         -1
# 7  Unknown / Non-Applicable                             -1       True
# 8  Unknown / Non-Applicable                             -1       True
# 9  Unknown / Non-Applicable                             -1         -1

# %% [markdown]
# # Data Cleaning / Transform

# %%
# drop unnecessary column in the data set
df.drop(['index'],axis=1,inplace=True)

# %%
#  header title lower
df.columns = map(str.lower, df.columns)

# %%
#  drop first column
df.drop(df.columns[0],axis=1,inplace=True)

# %%
# check null
print(df.isnull().sum()) 
print(df.info())
# Out:
# job title            0
# salary estimate      0
# job description      0
# rating               0
# company name         0
# location             0
# headquarters         0
# size                 0
# founded              0
# type of ownership    0
# industry             0
# sector               0
# revenue              0
# competitors          0
# easy apply           0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3909 entries, 0 to 3908
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   job title          3909 non-null   object
#  1   salary estimate    3909 non-null   object
#  2   job description    3909 non-null   object
#  3   rating             3909 non-null   float64
#  4   company name       3909 non-null   object
#  5   location           3909 non-null   object
#  6   headquarters       3909 non-null   object
#  7   size               3909 non-null   object
#  8   founded            3909 non-null   int64
#  9   type of ownership  3909 non-null   object
#  10  industry           3909 non-null   object
#  11  sector             3909 non-null   object
#  12  revenue            3909 non-null   object
#  13  competitors        3909 non-null   object
#  14  easy apply         3909 non-null   object
# dtypes: float64(1), int64(1), object(13)
# memory usage: 458.2+ KB
# None

# %%
# change the value -1 into false
df['easy apply'] = df['easy apply'].replace(['-1'],'False')
df['easy apply'] = df['easy apply'].replace(['TRUE'],'True')

df['job title'] = df['job title'].apply(lambda x:x.join(x.split(',')[:1]))
df['job title'] = df['job title'].apply(lambda x:x.join(x.split('/')[:1]))
df['job title'] = df['job title'].apply(lambda x:x.join(x.split(' - ')[:1]))

df['location'] = df['location'].apply(lambda x:x.join(x.split(',')[:1]))

df['headquarters'] = df['headquarters'].apply(lambda x:x.join(x.split(',')[:1]))
df.rename(columns = {'type of ownership':'ownership','salary estimate':'salary'}, inplace = True)
df['ownership'] = df['ownership'].apply(lambda x:x.split()[-1])
df['easy apply'] = df['easy apply'].replace(['-1'],'False')
df['easy apply'] = df['easy apply'].replace(['TRUE'],'True')
df['revenue'] = df['revenue'].apply(lambda x:x.split()[-1])
df['sector'] = df['sector'].replace(['-1'],np.nan)
df['ownership'] = df['ownership'].replace(['Unknown'],np.nan)
df['size'] = df['size'].replace([-1],np.nan)
df['founded'] = df['founded'].replace([-1],np.nan)
df['rating'] = df['rating'].replace([-1],np.nan)
df['company name'] = df['company name'].apply(lambda x:x.split()[0])
df = df.dropna(how='any',axis=0)
df = df.reset_index(drop=True)
df['salary'] = df['salary'].apply(lambda x:x.split()[0])
df['founded']=df['founded'].astype(int)
df['salary']=df['salary'].apply(lambda x:x.replace('$',''))
df['salary'] = df['salary'].apply(lambda x:x.replace('K',' '))
df['size'] = df['size'].apply(lambda x:x.replace('to','-'))
df['size'] = df['size'].apply(lambda x:x.replace('+',' - 0'))
df['size']= df['size'].apply(lambda x:x.replace('employees',' '))
df['salary']= df['salary'].apply(lambda x:x.replace('(Employer',' '))
def convert_sqft_to_num(x):
    tokens = x.split('-')
    if len(tokens) == 2:
        return (float(tokens[0])+float(tokens[1]))/2
    try:
        return float(x)
    except:
        return None
df['salary'] = df['salary'].apply(convert_sqft_to_num)
df['size']=df['size'].apply(convert_sqft_to_num)
def isrevenue(x):
    if x=="Non-Applicable":
        return 0
    elif x=="(USD)":
        return 1
df['revenue']=df['revenue'].apply(isrevenue)
df['job title'] = df['job title'].apply(lambda x:x.replace('#NAME?','-'))
df['job title'] = df['job title'].apply(lambda x:x.replace('with','-'))
print('\n','unique job titles are :',df['job title'].unique())
df.head(20)
# Out:
#  unique job titles are : ['Senior Data Scientist' 'Data Scientist' 'Data Analyst' ...
#  'Columbus Data Science Tutor Jobs' 'Cyber Security Data Engineer'
#  'Security Analytics Data Engineer']
#                   job title  salary  \
# 0     Senior Data Scientist   146.0
# 1            Data Scientist   146.0
# 2              Data Analyst   146.0
# 3                  Director   146.0
# 4            Data Scientist   146.0
# 5   Quantitative Researcher   146.0
# 6              AI Scientist   146.0
# 7   Quantitative Researcher   146.0
# 8            Data Scientist   146.0
# 9            Data Scientist   146.0
# 10           Data Scientist   146.0
# 11           Data Scientist   146.0
# 12           Data Scientist   146.0
# 13           Data Scientist   146.0
# 14           Data Scientist   146.0
# 15           Data Scientist   146.0
# 16           Data Scientist   146.0
# 17                       VP   146.0
# 18           Data Scientist   146.0
# 19    Senior Data Scientist   146.0
#
#                                       job description  rating company name  \
# 0   ABOUT HOPPER\n\nAt Hopper, we’re on a mission ...     3.5       Hopper
# 1   At Noom, we use scientifically proven methods ...     4.5         Noom
# 2   Sapphire Digital seeks a dynamic and driven mi...     3.4     Sapphire
# 3   Director, Data Science - (200537)\nDescription...     3.4       United
# 4   Job Brief\n\nThe ideal candidate will have pre...     2.9          IFG
# 5   Experience: Entry-level (PhD Program) or Exper...     4.4          PDT
# 6   Paige is a software company helping pathologis...     5.0        Paige
# 7   About the Position\n\n\nAt Jane Street, we con...     4.8         Jane
# 8   Company Description:\n\nQuartet is a pioneerin...     3.9      Quartet
# 9   PulsePoint™, a global programmatic advertising...     4.4   PulsePoint
# 10  Medidata: Conquering Diseases Together\n\nMedi...     4.3     Medidata
# 11  A Career with Point72’s MI Data team\nAt Point...     3.9      Point72
# 12  Two Sigma is a different kind of investment ma...     4.4          Two
# 13  Data Scientist\nAffinity Solutions / Marketing...     3.0     Affinity
# 14  Company DescriptionAs an Etsy employee, you ca...     3.6         Etsy
# 15  Data Scientist/ML Engineer\n\nApply Now\n\nBec...     3.3           PA
# 16  Job Description\nCompany Description\n\nAs an ...     3.6         Etsy
# 17  We are looking for a VP, Data Science to lead ...     3.9        7Park
# 18  Job Summary:Comprised of Disney's internationa...     4.0         Walt
# 19  We’re looking for a Senior Data Scientist who ...     3.4  Squarespace
#
#      location headquarters    size  founded ownership  \
# 0    New York     Montreal   750.5     2007   Private
# 1    New York     New York  3000.5     2008   Private
# 2   Lyndhurst    Lyndhurst   350.5     2019   Private
# 3    New York     New York   125.5     2007   Private
# 4    New York     Hartford   350.5     1985   Private
# 5    New York     New York   125.5     1993   Private
# 6    New York     New York    25.5     2018   Private
# 7    New York     New York   750.5     2000   Private
# 8    New York     New York   350.5     2014   Private
# 9    New York     New York   125.5     2011   Private
# 10   New York     New York  3000.5     1999    Public
# 11   New York     Stamford  3000.5     2014   Private
# 12   New York     New York  3000.5     2001   Private
# 13   New York     New York   125.5     1998   Private
# 14   Brooklyn     Brooklyn   750.5     2005    Public
# 15   New York       London  3000.5     1943   Private
# 16   New York     Brooklyn   750.5     2005    Public
# 17   New York     New York   125.5     2012   Private
# 18   New York      Burbank  5000.0     1923    Public
# 19   New York     New York  3000.5     2003   Private
#
#                                     industry                  sector  revenue  \
# 0                            Travel Agencies        Travel & Tourism        0
# 1                  Health, Beauty, & Fitness       Consumer Services        0
# 2                                   Internet  Information Technology        0
# 3                    Advertising & Marketing       Business Services        0
# 4                         Insurance Carriers               Insurance        0
# 5      Investment Banking & Asset Management                 Finance        0
# 6    Enterprise Software & Network Solutions  Information Technology        0
# 7      Investment Banking & Asset Management                 Finance        0
# 8    Enterprise Software & Network Solutions  Information Technology        0
# 9                                   Internet  Information Technology        1
# 10   Enterprise Software & Network Solutions  Information Technology        1
# 11     Investment Banking & Asset Management                 Finance        0
# 12     Investment Banking & Asset Management                 Finance        0
# 13                   Advertising & Marketing       Business Services        0
# 14                       Other Retail Stores                  Retail        1
# 15                                Consulting       Business Services        1
# 16                       Other Retail Stores                  Retail        1
# 17                    Research & Development       Business Services        0
# 18  Motion Picture Production & Distribution                   Media        1
# 19                                  Internet  Information Technology        0
#
#                                          competitors easy apply
# 0                                                 -1      False
# 1                                                 -1      False
# 2                               Zocdoc, Healthgrades      False
# 3                           BBDO, Grey Group, Droga5      False
# 4                      Colony Specialty, Markel, RLI      False
# 5                                                 -1      False
# 6                                                 -1       True
# 7                                                 -1      False
# 8                                                 -1       True
# 9   Crossix Solutions Inc., AppNexus, The Trade Desk      False
# 10                                            Oracle      False
# 11                                                -1      False
# 12                                                -1      False
# 13              Commerce Signals, Cardlytics, Yodlee       True
# 14                 Airbnb, Warby Parker, Kickstarter      False
# 15           McKinsey & Company, Accenture, Deloitte      False
# 16                 Airbnb, Warby Parker, Kickstarter      False
# 17                                                -1      False
# 18              News Corp, WarnerMedia, NBCUniversal      False
# 19                                           GoDaddy      False

# %% [markdown]
# # Load

# %%
df.to_csv('DataScientist_clean.csv')
